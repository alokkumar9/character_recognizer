# %%
import keras_ocr
import matplotlib.pyplot as plt
import gradio as gr

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\ALOK\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\ALOK\.keras-ocr\crnn_kurapan.h5

# %%
# Read images from folder path to image object
images = [
    keras_ocr.tools.read(img) for img in ['images\images_with_char/bookcover.png',
                                          'images\images_with_char/screen.png'
                                         ]
]

# %%
# generate text predictions from the images
prediction_groups = pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 33s 33s/step
# 1/1 [==============================] - 11s 11s/step

# %%
# plot the text predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, 
                                    predictions=predictions, 
                                    ax=ax)

# %%
# Out:
# Using cache found in C:\Users\ALOK/.cache\torch\hub\pytorch_vision_v0.6.0
# C:\Users\ALOK\AppData\Local\Temp\ipykernel_8432\3628683511.py:18: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   inputs=gr.inputs.Image(type="pil"),
# C:\Users\ALOK\AppData\Local\Temp\ipykernel_8432\3628683511.py:18: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   inputs=gr.inputs.Image(type="pil"),
# C:\Users\ALOK\AppData\Local\Temp\ipykernel_8432\3628683511.py:19: GradioDeprecationWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   outputs=gr.outputs.Label(num_top_classes=3),
# C:\Users\ALOK\AppData\Local\Temp\ipykernel_8432\3628683511.py:19: GradioUnusedKwargWarning: You have unused kwarg parameters in Label, please remove them: {'type': 'auto'}
#   outputs=gr.outputs.Label(num_top_classes=3),
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
